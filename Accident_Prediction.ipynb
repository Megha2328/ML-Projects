# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("asrs.csv",encoding='latin1')

# %%
df.head()
# Out:
#    Unnamed: 0    .ACN  Time.Date Time.Local Time Of Day  \
# 0           0  925545     201101              0001-0600
# 1           1  925546     201101              1801-2400
# 2           2  925559     201101              1801-2400
# 3           3  925560     201101              1201-1800
# 4           4  925563     201101              1201-1800
#
#   Place.Locale Reference Place.State Reference  \
# 0              ZNY.ARTCC                    NY
# 1              ZOB.ARTCC                    OH
# 2              ZZZ.Tower                    US
# 3              ZZZ.Tower                    US
# 4              ZOB.ARTCC                    OH
#
#    Place.Relative Position.Angle.Radial  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#    Place.Relative Position.Distance.Nautical Miles  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Place.Altitude.AGL.Single Value  Place.Altitude.MSL.Single Value  ...  \
# 0                              NaN                          19000.0  ...
# 1                              NaN                          33000.0  ...
# 2                              NaN                           6700.0  ...
# 3                              0.0                              NaN  ...
# 4                              NaN                          15000.0  ...
#
#   Events.When Detected Events.Result  \
# 0                  NaN             2
# 1                  NaN             3
# 2                  NaN             1
# 3                 Taxi             1
# 4            In-flight             1
#
#   Assessments.Contributing Factors / Situations Assessments.Primary Problem  \
# 0  Human Factors; Aircraft; Equipment / Tooling               Human Factors
# 1                                 Human Factors               Human Factors
# 2                                 Human Factors               Human Factors
# 3                                 Human Factors               Human Factors
# 4            Human Factors; Procedure; Staffing               Human Factors
#
#                                   Report 1.Narrative Report 1.Callback  \
# 0  [I was] working air carrier 1 at FL190. Sector...               NaN
# 1  I walked up to the sector to relieve a Control...               NaN
# 2  Aircraft X checked in on my frequency and I di...               NaN
# 3  Aircraft X; a CRJ2; landed Runway XXL and was ...               NaN
# 4  I was working combined sectors with no D-side....               NaN
#
#                                   Report 2.Narrative Report 2.Callback  \
# 0  Air carrier 1 [was] being worked by Sector 56 ...               NaN
# 1                                                NaN               NaN
# 2                                                NaN               NaN
# 3                                                NaN               NaN
# 4                                                NaN               NaN
#
#                                    Report 1.Synopsis  \
# 0  ZNY controllers and flight crew personnel desc...
# 1  Enroute Controller described an Operational De...
# 2  Tower Controller described a missed 'emergency...
# 3  Disabled aircraft causes airport authority to ...
# 4  ZOB Controller reported that when an aircraft ...
#
#    Unnamed: 96_level_0.Unnamed: 96_level_1
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
# [5 rows x 98 columns]

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        Unnamed: 0     .ACN  Time.Date Time.Local Time Of Day  \
# 0               0   925545     201101              0001-0600
# 1               1   925546     201101              1801-2400
# 2               2   925559     201101              1801-2400
# 3               3   925560     201101              1201-1800
# 4               4   925563     201101              1201-1800
# ...           ...      ...        ...                    ...
# 15290       15660  1152871     201402              1801-2400
# 15291       15661  1152887     201402              0001-0600
# 15292       15662  1152900     201402              1201-1800
# 15293       15663  1152910     201402              0601-1200
# 15294       15664  1152927     201402                    NaN
#
#       Place.Locale Reference Place.State Reference  \
# 0                  ZNY.ARTCC                    NY
# 1                  ZOB.ARTCC                    OH
# 2                  ZZZ.Tower                    US
# 3                  ZZZ.Tower                    US
# 4                  ZOB.ARTCC                    OH
# ...                      ...                   ...
# 15290             D10.TRACON                    TX
# 15291              ZNY.ARTCC                    NY
# 15292            ZZZ.Airport                    US
# 15293            MDW.Airport                    IL
# 15294                    NaN                   NaN
#
#        Place.Relative Position.Angle.Radial  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 15290                                   NaN
# 15291                                   NaN
# 15292                                   NaN
# 15293                                   NaN
# 15294                                   NaN
#
#        Place.Relative Position.Distance.Nautical Miles  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 15290                                              NaN
# 15291                                              NaN
# 15292                                              NaN
# 15293                                              NaN
# 15294                                              NaN
#
#        Place.Altitude.AGL.Single Value  Place.Altitude.MSL.Single Value  ...  \
# 0                                  NaN                          19000.0  ...
# 1                                  NaN                          33000.0  ...
# 2                                  NaN                           6700.0  ...
# 3                                  0.0                              NaN  ...
# 4                                  NaN                          15000.0  ...
# ...                                ...                              ...  ...
# 15290                              NaN                          10000.0  ...
# 15291                              NaN                          28000.0  ...
# 15292                              0.0                              NaN  ...
# 15293                              0.0                              NaN  ...
# 15294                              0.0                              NaN  ...
#
#           Events.When Detected Events.Result  \
# 0                          NaN             2
# 1                          NaN             3
# 2                          NaN             1
# 3                         Taxi             1
# 4                    In-flight             1
# ...                        ...           ...
# 15290                In-flight             2
# 15291                In-flight             2
# 15292                In-flight             2
# 15293                     Taxi             2
# 15294  Other Extended exposure             1
#
#       Assessments.Contributing Factors / Situations  \
# 0      Human Factors; Aircraft; Equipment / Tooling
# 1                                     Human Factors
# 2                                     Human Factors
# 3                                     Human Factors
# 4                Human Factors; Procedure; Staffing
# ...                                             ...
# 15290                 Airspace Structure; Procedure
# 15291  Procedure; Human Factors; Airspace Structure
# 15292                       Human Factors; Aircraft
# 15293                                 Human Factors
# 15294       Company Policy; Staffing; Human Factors
#
#       Assessments.Primary Problem  \
# 0                   Human Factors
# 1                   Human Factors
# 2                   Human Factors
# 3                   Human Factors
# 4                   Human Factors
# ...                           ...
# 15290          Airspace Structure
# 15291                   Ambiguous
# 15292               Human Factors
# 15293               Human Factors
# 15294              Company Policy
#
#                                       Report 1.Narrative Report 1.Callback  \
# 0      [I was] working air carrier 1 at FL190. Sector...               NaN
# 1      I walked up to the sector to relieve a Control...               NaN
# 2      Aircraft X checked in on my frequency and I di...               NaN
# 3      Aircraft X; a CRJ2; landed Runway XXL and was ...               NaN
# 4      I was working combined sectors with no D-side....               NaN
# ...                                                  ...               ...
# 15290  I was working the feeder east position. I had ...               NaN
# 15291  Aircraft X; an ISP arrival northeast bound rou...               NaN
# 15292  I was PF on takeoff after deicing. Weather at ...               NaN
# 15293  Taxiing into the gate and prior to entering th...               NaN
# 15294  Isn't pilot fatigue one of the primary causes ...               NaN
#
#                                       Report 2.Narrative Report 2.Callback  \
# 0      Air carrier 1 [was] being worked by Sector 56 ...               NaN
# 1                                                    NaN               NaN
# 2                                                    NaN               NaN
# 3                                                    NaN               NaN
# 4                                                    NaN               NaN
# ...                                                  ...               ...
# 15290  We immediately searched for the traffic and ha...               NaN
# 15291  On vector with New York Center near BRIGS Inte...               NaN
# 15292  Close to 80 KIAS; Master Caution illuminated. ...               NaN
# 15293                                                NaN               NaN
# 15294                                                NaN               NaN
#
#                                        Report 1.Synopsis  \
# 0      ZNY controllers and flight crew personnel desc...
# 1      Enroute Controller described an Operational De...
# 2      Tower Controller described a missed 'emergency...
# 3      Disabled aircraft causes airport authority to ...
# 4      ZOB Controller reported that when an aircraft ...
# ...                                                  ...
# 15290  An A319 on the DFW BYP6 Arrival at 11;000 FT i...
# 15291  A ZNY Controller and one of the plots involved...
# 15292  B737-300 flight crew experiences an aft cargo ...
# 15293  B737 Captain reports having to stop abruptly a...
# 15294                                                NaN
#
#        Unnamed: 96_level_0.Unnamed: 96_level_1
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 15290                                      NaN
# 15291                                      NaN
# 15292                                      NaN
# 15293                                      NaN
# 15294                                      NaN
#
# [15295 rows x 98 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15295 entries, 0 to 15294
# Data columns (total 98 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Unnamed: 0                                                     15295 non-null  int64
#  1    .ACN                                                          15295 non-null  int64
#  2   Time.Date                                                      15295 non-null  int64
#  3   Time.Local Time Of Day                                         14460 non-null  object
#  4   Place.Locale Reference                                         14834 non-null  object
#  5   Place.State Reference                                          14835 non-null  object
#  6   Place.Relative Position.Angle.Radial                           530 non-null    float64
#  7   Place.Relative Position.Distance.Nautical Miles                1350 non-null   float64
#  8   Place.Altitude.AGL.Single Value                                5649 non-null   float64
#  9   Place.Altitude.MSL.Single Value                                7464 non-null   float64
#  10  Environment.Flight Conditions                                  8416 non-null   object
#  11  Environment.Weather Elements / Visibility                      3871 non-null   object
#  12  Environment.Work Environment Factor                            127 non-null    object
#  13  Environment.Light                                              9350 non-null   object
#  14  Environment.Ceiling                                            3070 non-null   object
#  15  Environment.RVR.Single Value                                   148 non-null    object
#  16  Aircraft 1.ATC / Advisory                                      12474 non-null  object
#  17  Aircraft 1.Aircraft Operator                                   14086 non-null  object
#  18  Aircraft 1.Make Model Name                                     15266 non-null  object
#  19  Aircraft 1.Aircraft Zone                                       1 non-null      float64
#  20  Aircraft 1.Crew Size                                           13805 non-null  float64
#  21  Aircraft 1.Operating Under FAR Part                            14156 non-null  object
#  22  Aircraft 1.Flight Plan                                         10811 non-null  object
#  23  Aircraft 1.Mission                                             10918 non-null  object
#  24  Aircraft 1.Nav In Use                                          914 non-null    object
#  25  Aircraft 1.Flight Phase                                        14768 non-null  object
#  26  Aircraft 1.Route In Use                                        4051 non-null   object
#  27  Aircraft 1.Airspace                                            8894 non-null   object
#  28  Aircraft 1.Maintenance Status.Maintenance Deferred             518 non-null    object
#  29  Aircraft 1.Maintenance Status.Records Complete                 288 non-null    object
#  30  Aircraft 1.Maintenance Status.Released For Service             883 non-null    object
#  31  Aircraft 1.Maintenance Status.Required / Correct Doc On Board  136 non-null    object
#  32  Aircraft 1.Maintenance Status.Maintenance Type                 900 non-null    object
#  33  Aircraft 1.Maintenance Status.Maintenance Items Involved       832 non-null    object
#  34  Aircraft 1.Cabin Lighting                                      50 non-null     object
#  35  Aircraft 1.Number Of Seats.Number                              30 non-null     float64
#  36  Aircraft 1.Passengers On Board.Number                          30 non-null     float64
#  37  Aircraft 1.Crew Size Flight Attendant.Number Of Crew           28 non-null     float64
#  38  Component.Aircraft Component                                   7804 non-null   object
#  39  Component.Manufacturer                                         650 non-null    object
#  40  Component.Aircraft Reference                                   7621 non-null   object
#  41  Component.Problem                                              7030 non-null   object
#  42  Aircraft 2.ATC / Advisory                                      1885 non-null   object
#  43  Aircraft 2.Aircraft Operator                                   1276 non-null   object
#  44  Aircraft 2.Make Model Name                                     2228 non-null   object
#  45  Aircraft 2.Aircraft Zone                                       0 non-null      float64
#  46  Aircraft 2.Crew Size                                           1677 non-null   float64
#  47  Aircraft 2.Operating Under FAR Part                            1365 non-null   object
#  48  Aircraft 2.Flight Plan                                         1251 non-null   object
#  49  Aircraft 2.Mission                                             486 non-null    object
#  50  Aircraft 2.Nav In Use                                          60 non-null     object
#  51  Aircraft 2.Flight Phase                                        1946 non-null   object
#  52  Aircraft 2.Route In Use                                        436 non-null    object
#  53  Aircraft 2.Airspace                                            1701 non-null   object
#  54  Aircraft 2.Maintenance Status.Maintenance Deferred             0 non-null      float64
#  55  Aircraft 2.Maintenance Status.Records Complete                 0 non-null      float64
#  56  Aircraft 2.Maintenance Status.Released For Service             0 non-null      float64
#  57  Aircraft 2.Maintenance Status.Required / Correct Doc On Board  0 non-null      float64
#  58  Aircraft 2.Maintenance Status.Maintenance Type                 2 non-null      object
#  59  Aircraft 2.Maintenance Status.Maintenance Items Involved       2 non-null      object
#  60  Aircraft 2.Cabin Lighting                                      0 non-null      float64
#  61  Aircraft 2.Number Of Seats.Number                              0 non-null      float64
#  62  Aircraft 2.Passengers On Board.Number                          0 non-null      float64
#  63  Aircraft 2.Crew Size Flight Attendant.Number Of Crew           0 non-null      float64
#  64  Person 1.Location Of Person                                    15108 non-null  object
#  65  Person 1.Location In Aircraft                                  11759 non-null  object
#  66  Person 1.Reporter Organization                                 15154 non-null  object
#  67  Person 1.Function                                              15124 non-null  object
#  68  Person 1.Qualification                                         13191 non-null  object
#  69  Person 1.Experience                                            6403 non-null   object
#  70  Person 1.Cabin Activity                                        188 non-null    object
#  71  Person 1.Human Factors                                         11928 non-null  object
#  72  Person 1.Communication Breakdown                               4422 non-null   object
#  73  Person 1.ASRS Report Number.Accession Number                   15295 non-null  int64
#  74  Person 2.Location Of Person                                    3685 non-null   object
#  75  Person 2.Location In Aircraft                                  3229 non-null   object
#  76  Person 2.Reporter Organization                                 3706 non-null   object
#  77  Person 2.Function                                              3705 non-null   object
#  78  Person 2.Qualification                                         2551 non-null   object
#  79  Person 2.Experience                                            1364 non-null   object
#  80  Person 2.Cabin Activity                                        29 non-null     object
#  81  Person 2.Human Factors                                         1867 non-null   object
#  82  Person 2.Communication Breakdown                               627 non-null    object
#  83  Person 2.ASRS Report Number.Accession Number                   3718 non-null   float64
#  84  Events.Anomaly                                                 15292 non-null  object
#  85  Events.Miss Distance                                           789 non-null    object
#  86  Events.Were Passengers Involved In Event                       3539 non-null   object
#  87  Events.Detector                                                15207 non-null  object
#  88  Events.When Detected                                           13013 non-null  object
#  89  Events.Result                                                  15295 non-null  int64
#  90  Assessments.Contributing Factors / Situations                  15261 non-null  object
#  91  Assessments.Primary Problem                                    15261 non-null  object
#  92  Report 1.Narrative                                             15295 non-null  object
#  93  Report 1.Callback                                              921 non-null    object
#  94  Report 2.Narrative                                             3417 non-null   object
#  95  Report 2.Callback                                              77 non-null     object
#  96  Report 1.Synopsis                                              15294 non-null  object
#  97  Unnamed: 96_level_0.Unnamed: 96_level_1                        0 non-null      float64
# dtypes: float64(21), int64(5), object(72)
# memory usage: 11.4+ MB

# %%
df.columns.isnull()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False])

# %%
# Convert specific columns to numeric after cleaning if necessary
df['Aircraft 1.Number Of Seats.Number'] = pd.to_numeric(df['Aircraft 1.Number Of Seats.Number'], errors='coerce')
df['Aircraft 1.Passengers On Board.Number'] = pd.to_numeric(df['Aircraft 1.Passengers On Board.Number'], errors='coerce')
df['Aircraft 1.Crew Size Flight Attendant.Number Of Crew'] = pd.to_numeric(df['Aircraft 1.Crew Size Flight Attendant.Number Of Crew'], errors='coerce')
df['Aircraft 2.Number Of Seats.Number'] = pd.to_numeric(df['Aircraft 2.Number Of Seats.Number'], errors='coerce')
df['Aircraft 2.Passengers On Board.Number'] = pd.to_numeric(df['Aircraft 2.Passengers On Board.Number'], errors='coerce')
df['Aircraft 2.Crew Size Flight Attendant.Number Of Crew'] = pd.to_numeric(df['Aircraft 2.Crew Size Flight Attendant.Number Of Crew'], errors='coerce')

# Remove non-numeric characters and convert where applicable
df['Environment.Ceiling'] = df['Environment.Ceiling'].str.replace('ft', '').astype(float, errors='ignore')
df['Events.Miss Distance'] = pd.to_numeric(df['Events.Miss Distance'], errors='coerce')

# %%
categorical_cols=[i for i in df.columns if df[i].dtype=='object']
numerical_cols=[i for i in df.columns if df[i].dtype!='object']

# %%
df['Place.Altitude.MSL.Single Value'].hist(bins=30)
plt.title('Altitude Distribution')
plt.xlabel('Altitude (MSL)')
plt.ylabel('Frequency')
plt.show()

# %%
df['Environment.Flight Conditions'].value_counts().plot(kind='bar')
plt.title('Flight Conditions Frequency')
plt.xlabel('Flight Conditions')
plt.ylabel('Count')
plt.show()

# %%
# Distribution of Events.Result by Flight Phase
plt.figure(figsize=(12,6))
sns.boxplot(x='Aircraft 1.Flight Phase', y='Events.Result', data=df)
plt.title('Distribution of Events.Result by Flight Phase')
plt.xticks(rotation=90)
plt.show()

# %%
# Distribution of Events.Result by Flight Conditions
plt.figure(figsize=(12,6))
sns.countplot(x='Environment.Flight Conditions', hue='Events.Result', data=df)
plt.title('Distribution of Events.Result by Flight Conditions')
plt.xticks(rotation=45)
plt.show()

# %%
# Distribution of Assessments.Primary Problem by Altitude
plt.figure(figsize=(12,6))
sns.boxplot(x='Assessments.Primary Problem', y='Place.Altitude.MSL.Single Value', data=df)
plt.title('Distribution of Assessments.Primary Problem by Altitude')
plt.show()

# %%
# Distribution of Assessments.Primary Problem by Flight Conditions
plt.figure(figsize=(12,6))
sns.countplot(x='Environment.Flight Conditions', hue='Assessments.Primary Problem', data=df)
plt.title('Distribution of Assessments.Primary Problem by Flight Conditions')
plt.xticks(rotation=45)
plt.show()

# %%
numeric_df=df.select_dtypes(include=['float64','int64'])
numeric_df_dropped = numeric_df.dropna(thresh=int(0.8 * len(numeric_df)), axis=1)

data = numeric_df_dropped.corr()

plt.figure(figsize=(12,8))
sns.heatmap(data, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
plt.figure(figsize=(25,20))
x=1;
for i in numerical_cols:
    if x<len(numerical_cols):
        ax=plt.subplot(9,3,x)
        sns.distplot(df[i])
        plt.xlabel(i)
    x+=1;
plt.tight_layout()
plt.show()

# %%
df[numerical_cols].isna().sum().sort_values(ascending=False)
# Out:
# Unnamed: 96_level_0.Unnamed: 96_level_1                          15295
# Aircraft 2.Maintenance Status.Required / Correct Doc On Board    15295
# Aircraft 2.Maintenance Status.Records Complete                   15295
# Aircraft 2.Maintenance Status.Maintenance Deferred               15295
# Aircraft 2.Cabin Lighting                                        15295
# Aircraft 2.Aircraft Zone                                         15295
# Aircraft 2.Number Of Seats.Number                                15295
# Aircraft 2.Passengers On Board.Number                            15295
# Aircraft 2.Crew Size Flight Attendant.Number Of Crew             15295
# Events.Miss Distance                                             15295
# Aircraft 2.Maintenance Status.Released For Service               15295
# Aircraft 1.Aircraft Zone                                         15294
# Aircraft 1.Crew Size Flight Attendant.Number Of Crew             15267
# Aircraft 1.Number Of Seats.Number                                15265
# Aircraft 1.Passengers On Board.Number                            15265
# Place.Relative Position.Angle.Radial                             14765
# Place.Relative Position.Distance.Nautical Miles                  13945
# Aircraft 2.Crew Size                                             13618
# Person 2.ASRS Report Number.Accession Number                     11577
# Place.Altitude.AGL.Single Value                                   9646
# Place.Altitude.MSL.Single Value                                   7831
# Aircraft 1.Crew Size                                              1490
#  .ACN                                                                0
# Person 1.ASRS Report Number.Accession Number                         0
# Time.Date                                                            0
# Events.Result                                                        0
# Unnamed: 0                                                           0
# dtype: int64

# %%
df[categorical_cols].isna().sum().sort_values(ascending=False)
# Out:
# Aircraft 2.Maintenance Status.Maintenance Items Involved    15293
# Aircraft 2.Maintenance Status.Maintenance Type              15293
# Person 2.Cabin Activity                                     15266
# Aircraft 1.Cabin Lighting                                   15245
# Aircraft 2.Nav In Use                                       15235
#                                                             ...
# Assessments.Primary Problem                                    34
# Aircraft 1.Make Model Name                                     29
# Events.Anomaly                                                  3
# Report 1.Synopsis                                               1
# Report 1.Narrative                                              0
# Length: 71, dtype: int64

# %%
def fill_nulls_with_mode_in_categorical(df):
    categorical_cols = df.select_dtypes(include=['object', 'category']).columns
    
    for column in categorical_cols:
        mode_series = df[column].mode(dropna=True)
        
        if not mode_series.empty:
            mode_value = mode_series[0]  
            df[column].fillna(mode_value, inplace=True)
        else:
            print(f"Column '{column}' has only NaN values; cannot calculate mode.")
    
    null_counts = df[categorical_cols].isna().sum()
    print("Null values in categorical columns after filling:")
    print(null_counts)
    
    return df

# %%
df=fill_nulls_with_mode_in_categorical(df)
# Out:
# Null values in categorical columns after filling:
# Time.Local Time Of Day                       0
# Place.Locale Reference                       0
# Place.State Reference                        0
# Environment.Flight Conditions                0
# Environment.Weather Elements / Visibility    0
#                                             ..
# Report 1.Narrative                           0
# Report 1.Callback                            0
# Report 2.Narrative                           0
# Report 2.Callback                            0
# Report 1.Synopsis                            0
# Length: 71, dtype: int64

# %%
def fill_nulls_with_mode_in_numerical(df):
    categorical_cols = df.select_dtypes(include=['float64', 'int64']).columns
    
    for column in numerical_cols:
        mode_series = df[column].mode(dropna=True)
        
        if not mode_series.empty:
            mode_value = mode_series[0]  
            df[column].fillna(mode_value, inplace=True)
        else:
            print(f"Column '{column}' has only NaN values; cannot calculate mode.")
    
    null_counts = df[numerical_cols].isna().sum()
    print("Null values in numerical columns after filling:")
    print(null_counts)
    
    return df

# %%
df=fill_nulls_with_mode_in_numerical(df)
# Out:
# Column 'Aircraft 2.Aircraft Zone' has only NaN values; cannot calculate mode.
# Column 'Aircraft 2.Maintenance Status.Maintenance Deferred' has only NaN values; cannot calculate mode.
# Column 'Aircraft 2.Maintenance Status.Records Complete' has only NaN values; cannot calculate mode.
# Column 'Aircraft 2.Maintenance Status.Released For Service' has only NaN values; cannot calculate mode.
# Column 'Aircraft 2.Maintenance Status.Required / Correct Doc On Board' has only NaN values; cannot calculate mode.
# Column 'Aircraft 2.Cabin Lighting' has only NaN values; cannot calculate mode.
# Column 'Aircraft 2.Number Of Seats.Number' has only NaN values; cannot calculate mode.
# Column 'Aircraft 2.Passengers On Board.Number' has only NaN values; cannot calculate mode.
# Column 'Aircraft 2.Crew Size Flight Attendant.Number Of Crew' has only NaN values; cannot calculate mode.
# Column 'Events.Miss Distance' has only NaN values; cannot calculate mode.
# Column 'Unnamed: 96_level_0.Unnamed: 96_level_1' has only NaN values; cannot calculate mode.
# Null values in numerical columns after filling:
# Unnamed: 0                                                           0
#  .ACN                                                                0
# Time.Date                                                            0
# Place.Relative Position.Angle.Radial                                 0
# Place.Relative Position.Distance.Nautical Miles                      0
# Place.Altitude.AGL.Single Value                                      0
# Place.Altitude.MSL.Single Value                                      0
# Aircraft 1.Aircraft Zone                                             0
# Aircraft 1.Crew Size                                                 0
# Aircraft 1.Number Of Seats.Number                                    0
# Aircraft 1.Passengers On Board.Number                                0
# Aircraft 1.Crew Size Flight Attendant.Number Of Crew                 0
# Aircraft 2.Aircraft Zone                                         15295
# Aircraft 2.Crew Size                                                 0
# Aircraft 2.Maintenance Status.Maintenance Deferred               15295
# Aircraft 2.Maintenance Status.Records Complete                   15295
# Aircraft 2.Maintenance Status.Released For Service               15295
# Aircraft 2.Maintenance Status.Required / Correct Doc On Board    15295
# Aircraft 2.Cabin Lighting                                        15295
# Aircraft 2.Number Of Seats.Number                                15295
# Aircraft 2.Passengers On Board.Number                            15295
# Aircraft 2.Crew Size Flight Attendant.Number Of Crew             15295
# Person 1.ASRS Report Number.Accession Number                         0
# Person 2.ASRS Report Number.Accession Number                         0
# Events.Miss Distance                                             15295
# Events.Result                                                        0
# Unnamed: 96_level_0.Unnamed: 96_level_1                          15295
# dtype: int64

# %%
from sklearn import preprocessing

label_encoder=preprocessing.LabelEncoder()
for i in categorical_cols:
    df[i]=label_encoder.fit_transform(df[i])

# %%
df.head()
# Out:
#    Unnamed: 0    .ACN  Time.Date  Time.Local Time Of Day  \
# 0           0  925545     201101                       0
# 1           1  925546     201101                       3
# 2           2  925559     201101                       3
# 3           3  925560     201101                       2
# 4           4  925563     201101                       2
#
#    Place.Locale Reference  Place.State Reference  \
# 0                    1144                     40
# 1                    1146                     41
# 2                    1160                     53
# 3                    1160                     53
# 4                    1146                     41
#
#    Place.Relative Position.Angle.Radial  \
# 0                                 270.0
# 1                                 270.0
# 2                                 270.0
# 3                                 270.0
# 4                                 270.0
#
#    Place.Relative Position.Distance.Nautical Miles  \
# 0                                             10.0
# 1                                             10.0
# 2                                             10.0
# 3                                             10.0
# 4                                             10.0
#
#    Place.Altitude.AGL.Single Value  Place.Altitude.MSL.Single Value  ...  \
# 0                              0.0                          19000.0  ...
# 1                              0.0                          33000.0  ...
# 2                              0.0                           6700.0  ...
# 3                              0.0                           3000.0  ...
# 4                              0.0                          15000.0  ...
#
#    Events.When Detected  Events.Result  \
# 0                     8              2
# 1                     8              3
# 2                     8              1
# 3                   189              1
# 4                     8              1
#
#    Assessments.Contributing Factors / Situations  Assessments.Primary Problem  \
# 0                                           1016                            9
# 1                                            992                            9
# 2                                            992                            9
# 3                                            992                            9
# 4                                           1223                            9
#
#    Report 1.Narrative  Report 1.Callback  Report 2.Narrative  \
# 0               14887                  0                 238
# 1                6118                  0                2765
# 2                1605                  0                2765
# 3                1708                  0                2765
# 4                7589                  0                2765
#
#    Report 2.Callback  Report 1.Synopsis  \
# 0                  0              15144
# 1                  0              10914
# 2                  0              13895
# 3                  0              10323
# 4                  0              15190
#
#    Unnamed: 96_level_0.Unnamed: 96_level_1
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
# [5 rows x 98 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, recall_score

df = df[df['Events.Result'].isin([1, 2, 3])]
df = df[df['Assessments.Primary Problem'].isin([1, 2, 3])]

y_result = df['Events.Result'].map({1: 0, 2: 1, 3: 2})
y_problem = df['Assessments.Primary Problem'].map({1: 0, 2: 1, 3: 2})
X = df.drop(columns=['Events.Result', 'Assessments.Primary Problem'])

X_train_result, X_test_result, y_train_result, y_test_result = train_test_split(
    X, y_result, test_size=0.2, random_state=42
)
X_train_problem, X_test_problem, y_train_problem, y_test_problem = train_test_split(
    X, y_problem, test_size=0.2, random_state=42
)

model = RandomForestClassifier(random_state=42, n_estimators=100)

# Evaluate for Events.Result
model.fit(X_train_result, y_train_result)
y_pred_result = model.predict(X_test_result)

accuracy_result = accuracy_score(y_test_result, y_pred_result)
f1_result = f1_score(y_test_result, y_pred_result, average='weighted')
recall_result = recall_score(y_test_result, y_pred_result, average='weighted')
conf_matrix_result = confusion_matrix(y_test_result, y_pred_result)

# Evaluate for Assessments.Primary Problem
model.fit(X_train_problem, y_train_problem)
y_pred_problem = model.predict(X_test_problem)

accuracy_problem = accuracy_score(y_test_problem, y_pred_problem)
f1_problem = f1_score(y_test_problem, y_pred_problem, average='weighted')
recall_problem = recall_score(y_test_problem, y_pred_problem, average='weighted')
conf_matrix_problem = confusion_matrix(y_test_problem, y_pred_problem)

# Print metrics
print("Metrics for Events.Result Model:")
print(f"Accuracy: {accuracy_result:.2f}, F1-Score: {f1_result:.2f}, Recall: {recall_result:.2f}")

print("\nMetrics for Assessments.Primary Problem Model:")
print(f"Accuracy: {accuracy_problem:.2f}, F1-Score: {f1_problem:.2f}, Recall: {recall_problem:.2f}")

# Plot confusion matrices
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

sns.heatmap(conf_matrix_result, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title("Confusion Matrix: Events.Result")
axes[0].set_xlabel("Predicted")
axes[0].set_ylabel("Actual")

sns.heatmap(conf_matrix_problem, annot=True, fmt='d', cmap='Greens', ax=axes[1])
axes[1].set_title("Confusion Matrix: Assessments.Primary Problem")
axes[1].set_xlabel("Predicted")
axes[1].set_ylabel("Actual")

plt.tight_layout()
plt.show()

# Compare metrics using a bar chart
metrics = {
    "Metric": ["Accuracy", "F1-Score", "Recall"],
    "Events.Result": [accuracy_result, f1_result, recall_result],
    "Assessments.Primary Problem": [accuracy_problem, f1_problem, recall_problem],
}

metrics_df = pd.DataFrame(metrics)

metrics_df.plot(
    x="Metric",
    kind="bar",
    figsize=(10, 6),
    color=["skyblue", "lightgreen"],
    edgecolor="black",
)
plt.title("Metrics Comparison for Events.Result and Assessments.Primary Problem")
plt.ylabel("Score")
plt.ylim(0, 1)
plt.legend(title="Target Column", loc="lower right")
plt.show()
# Out:
# Metrics for Events.Result Model:
# Accuracy: 0.64, F1-Score: 0.61, Recall: 0.64
#
# Metrics for Assessments.Primary Problem Model:
# Accuracy: 0.99, F1-Score: 0.99, Recall: 0.99

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, recall_score
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.model_selection import train_test_split

df = df[df['Events.Result'].isin([1, 2, 3])]
df = df[df['Assessments.Primary Problem'].isin([1, 2, 3])]

y_result = df['Events.Result'].map({1: 0, 2: 1, 3: 2})
y_problem = df['Assessments.Primary Problem'].map({1: 0, 2: 1, 3: 2})
X = df.drop(columns=['Events.Result', 'Assessments.Primary Problem'])

X_train_result, X_test_result, y_train_result, y_test_result = train_test_split(
    X, y_result, test_size=0.2, random_state=42
)
X_train_problem, X_test_problem, y_train_problem, y_test_problem = train_test_split(
    X, y_problem, test_size=0.2, random_state=42
)

model = HistGradientBoostingClassifier(random_state=42)

# Evaluate for Events.Result
model.fit(X_train_result, y_train_result)
y_pred_result = model.predict(X_test_result)

accuracy_result = accuracy_score(y_test_result, y_pred_result)
f1_result = f1_score(y_test_result, y_pred_result, average='weighted')
recall_result = recall_score(y_test_result, y_pred_result, average='weighted')
conf_matrix_result = confusion_matrix(y_test_result, y_pred_result)

# Evaluate for Assessments.Primary Problem
model.fit(X_train_problem, y_train_problem)
y_pred_problem = model.predict(X_test_problem)

accuracy_problem = accuracy_score(y_test_problem, y_pred_problem)
f1_problem = f1_score(y_test_problem, y_pred_problem, average='weighted')
recall_problem = recall_score(y_test_problem, y_pred_problem, average='weighted')
conf_matrix_problem = confusion_matrix(y_test_problem, y_pred_problem)

# Print metrics
print("Metrics for Events.Result Model:")
print(f"Accuracy: {accuracy_result:.2f}, F1-Score: {f1_result:.2f}, Recall: {recall_result:.2f}")

print("\nMetrics for Assessments.Primary Problem Model:")
print(f"Accuracy: {accuracy_problem:.2f}, F1-Score: {f1_problem:.2f}, Recall: {recall_problem:.2f}")

# Plot confusion matrices
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

sns.heatmap(conf_matrix_result, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title("Confusion Matrix: Events.Result")
axes[0].set_xlabel("Predicted")
axes[0].set_ylabel("Actual")

sns.heatmap(conf_matrix_problem, annot=True, fmt='d', cmap='Greens', ax=axes[1])
axes[1].set_title("Confusion Matrix: Assessments.Primary Problem")
axes[1].set_xlabel("Predicted")
axes[1].set_ylabel("Actual")

plt.tight_layout()
plt.show()

# Compare metrics using a bar chart
metrics = {
    "Metric": ["Accuracy", "F1-Score", "Recall"],
    "Events.Result": [accuracy_result, f1_result, recall_result],
    "Assessments.Primary Problem": [accuracy_problem, f1_problem, recall_problem],
}

metrics_df = pd.DataFrame(metrics)

metrics_df.plot(
    x="Metric",
    kind="bar",
    figsize=(10, 6),
    color=["skyblue", "lightgreen"],
    edgecolor="black",
)
plt.title("Metrics Comparison for Events.Result and Assessments.Primary Problem")
plt.ylabel("Score")
plt.ylim(0, 1)
plt.legend(title="Target Column", loc="lower right")
plt.show()
# Out:
# Metrics for Events.Result Model:
# Accuracy: 0.66, F1-Score: 0.65, Recall: 0.66
#
# Metrics for Assessments.Primary Problem Model:
# Accuracy: 0.99, F1-Score: 0.99, Recall: 0.99

# %%
from xgboost import XGBClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, recall_score
from sklearn.model_selection import train_test_split

df = df[df['Events.Result'].isin([1, 2, 3])]
df = df[df['Assessments.Primary Problem'].isin([1, 2, 3])]

y_result = df['Events.Result'].map({1: 0, 2: 1, 3: 2})
y_problem = df['Assessments.Primary Problem'].map({1: 0, 2: 1, 3: 2})
X = df.drop(columns=['Events.Result', 'Assessments.Primary Problem'])

X_train_result, X_test_result, y_train_result, y_test_result = train_test_split(
    X, y_result, test_size=0.2, random_state=42
)
X_train_problem, X_test_problem, y_train_problem, y_test_problem = train_test_split(
    X, y_problem, test_size=0.2, random_state=42
)

model = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)

# Evaluate for Events.Result
model.fit(X_train_result, y_train_result)
y_pred_result = model.predict(X_test_result)

accuracy_result = accuracy_score(y_test_result, y_pred_result)
f1_result = f1_score(y_test_result, y_pred_result, average='weighted')
recall_result = recall_score(y_test_result, y_pred_result, average='weighted')
conf_matrix_result = confusion_matrix(y_test_result, y_pred_result)

# Evaluate for Assessments.Primary Problem
model.fit(X_train_problem, y_train_problem)
y_pred_problem = model.predict(X_test_problem)

accuracy_problem = accuracy_score(y_test_problem, y_pred_problem)
f1_problem = f1_score(y_test_problem, y_pred_problem, average='weighted')
recall_problem = recall_score(y_test_problem, y_pred_problem, average='weighted')
conf_matrix_problem = confusion_matrix(y_test_problem, y_pred_problem)

# Print metrics
print("Metrics for Events.Result Model:")
print(f"Accuracy: {accuracy_result:.2f}, F1-Score: {f1_result:.2f}, Recall: {recall_result:.2f}")

print("\nMetrics for Assessments.Primary Problem Model:")
print(f"Accuracy: {accuracy_problem:.2f}, F1-Score: {f1_problem:.2f}, Recall: {recall_problem:.2f}")

# Plot confusion matrices
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

sns.heatmap(conf_matrix_result, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title("Confusion Matrix: Events.Result")
axes[0].set_xlabel("Predicted")
axes[0].set_ylabel("Actual")

sns.heatmap(conf_matrix_problem, annot=True, fmt='d', cmap='Greens', ax=axes[1])
axes[1].set_title("Confusion Matrix: Assessments.Primary Problem")
axes[1].set_xlabel("Predicted")
axes[1].set_ylabel("Actual")

plt.tight_layout()
plt.show()

# Compare metrics using a bar chart
metrics = {
    "Metric": ["Accuracy", "F1-Score", "Recall"],
    "Events.Result": [accuracy_result, f1_result, recall_result],
    "Assessments.Primary Problem": [accuracy_problem, f1_problem, recall_problem],
}

metrics_df = pd.DataFrame(metrics)

metrics_df.plot(
    x="Metric",
    kind="bar",
    figsize=(10, 6),
    color=["skyblue", "lightgreen"],
    edgecolor="black",
)
plt.title("Metrics Comparison for Events.Result and Assessments.Primary Problem")
plt.ylabel("Score")
plt.ylim(0, 1)
plt.legend(title="Target Column", loc="lower right")
plt.show()
# Out:
# Metrics for Events.Result Model:
# Accuracy: 0.66, F1-Score: 0.64, Recall: 0.66
#
# Metrics for Assessments.Primary Problem Model:
# Accuracy: 0.99, F1-Score: 0.99, Recall: 0.99
